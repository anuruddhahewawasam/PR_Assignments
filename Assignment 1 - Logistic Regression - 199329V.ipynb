# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Loading Data

# %%
df=pd.read_csv("Data\\breast_cancer_wisconsin_data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# compactness_se             569 non-null float64
# concavity_se               569 non-null float64
# concave points_se          569 non-null float64
# symmetry_se                569 non-null float64
# fractal_dimension_se       569 non-null float64
# radius_worst               569 non-null float64
# texture_worst              569 non-null float64
# perimeter_worst            569 non-null float64
# area_worst                 569 non-null float64
# smoothness_worst           569 non-null float64
# compactness_worst          569 non-null float64
# concavity_worst            569 non-null float64
# concave points_worst       569 non-null float64
# symmetry_worst             569 non-null float64
# fractal_dimension_worst    569 non-null float64
# Unnamed: 32                0 non-null float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %% [markdown]
# ## Processing Data

# %%
#Dropping the 'id' column from the dataset
df=df.drop("id",1)
df=df.drop("Unnamed: 32",1)
    
#Mapping M to 1 and B to 0 in the output Label DataFrame
df['diagnosis']=df['diagnosis'].map({'M':1,'B':0})
    
    
#Split Data into training and test (65% and 34%)
train, test = train_test_split(df, test_size = 0.34, random_state=1)

#Training Data
train_x=train.loc[:,'radius_mean' : 'radius_worst']
train_y=train.loc[:,['diagnosis']]
    
#Testing Data
test_x=test.loc[:,'radius_mean' : 'radius_worst']
test_y=test.loc[:,['diagnosis']]
    
#Converting Traing and Test Data to numpy array
train_x=np.asarray(train_x)
train_y=np.asarray(train_y)
test_x=np.asarray(test_x)
test_y=np.asarray(test_y)

# %%
sns.lmplot(data=train, x='radius_mean', y='radius_worst', hue="diagnosis", fit_reg=False, height=12, aspect=1.5)

# %% [markdown]
# ## Helper Functions

# %%
#Function to initialize the weights and bias
def initialize(m):
    
    w = np.zeros((m,1))
    b = 0
    
    return w , b
    
#Function to calculate sigmoid of x    
def sigmoid(X):
    return 1/(1 + np.exp(- X))    


#Function for doing forward and back propogation
def propogate(X, Y, w, b):
    
    m = X.shape[1] #Number of training examples

    #Forward Propogation, calculating the cost
    Z = np.dot(w.T, X) + b;    
    A = sigmoid(Z)
    cost= -(1/m) * np.sum(Y * np.log(A) + (1-Y) * np.log(1-A))
    
    #Back Propogation , calculating the gradients
    dw = (1/m)* np.dot(X, (A-Y).T)
    db = (1/m)* np.sum(A-Y)
    
    grads= {"dw" : dw, "db" : db}
    
    return grads, cost
    
    


#Function for performing Grdient Descent
def optimize(X, Y, w, b, num_of_iterations, alpha):
    
    costs=[] 
    
    for i in range(num_of_iterations):
 
        grads, cost = propogate(X, Y, w, b)
        
        dw = grads["dw"]
        db = grads["db"]
        
        w = w - alpha * dw
        b = b - alpha * db
        
        #Storing the cost at interval of every 10 iterations
        if i% 10 == 0:
            costs.append(cost)
            print("cost after %i iteration : %f" % (i, cost))
            
            
    parameters = {"w":w, "b":b}
    grads = {"dw":dw, "db":db}
    
    
    return parameters, grads, costs


#Function for doing the predictions on the data set (mapping probabilities to 0 or 1)
def predict(X, w, b):
    
    m = X.shape[1] #Number of training examples
    
    y_prediction =  np.zeros((1,m))
    
    w = w.reshape(X.shape[0], 1)
    
    A=sigmoid(np.dot(w.T, X)+b)
    
    
    for i in range(A.shape[1]):
        
        if(A[0,i]<0.5):
            y_prediction[0,i]=0
        else:
            y_prediction[0,i]=1
            
    
    return y_prediction

# %% [markdown]
# ## Logistic Regression Model

# %%
#Function for calculating the Logistic Regression Model
def model(Xtrain, Ytrain, num_of_iterations, alpha):
    
    dim = Xtrain.shape[0] #Number of features
    
    w,b = initialize(dim)
    
    parameters, grads, costs = optimize(Xtrain, Ytrain, w, b, num_of_iterations, alpha) 
    
    w = parameters["w"]
    b = parameters["b"]
        
    
    d={"w":w, "b":b, "costs": costs}
    
    return d

# %% [markdown]
# ## Accuracy

# %%
def accuracy():           
    #Calling the model function to train a Logistic Regression Model on Training Data
    d= model(train_x.T, train_y.T, num_of_iterations=3000, alpha=0.000001)
    
        
    costs=d["costs"]
    w=d["w"]
    b=d["b"]
    
    
    #Now, calculating the accuracy on Training and Test Data
    Y_prediction_train = predict(train_x.T, w, b)
    Y_prediction_test = predict(test_x.T, w, b)
    
    
    
    print("\nTrain accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - train_y.T)) * 100))
    
    print("\nTest accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - test_y.T)) * 100))

#Calling the accuracy function to output the results
accuracy()
# Out:
# cost after 0 iteration : 0.693147
# cost after 10 iteration : 0.682212
# cost after 20 iteration : 0.680898
# cost after 30 iteration : 0.679999
# cost after 40 iteration : 0.679124
# cost after 50 iteration : 0.678254
# cost after 60 iteration : 0.677389
# cost after 70 iteration : 0.676528
# cost after 80 iteration : 0.675671
# cost after 90 iteration : 0.674818
# cost after 100 iteration : 0.673969
# cost after 110 iteration : 0.673125
# cost after 120 iteration : 0.672284
# cost after 130 iteration : 0.671448
# cost after 140 iteration : 0.670616
# cost after 150 iteration : 0.669787
# cost after 160 iteration : 0.668963
# cost after 170 iteration : 0.668143
# cost after 180 iteration : 0.667326
# cost after 190 iteration : 0.666513
# cost after 200 iteration : 0.665704
# cost after 210 iteration : 0.664899
# cost after 220 iteration : 0.664097
# cost after 230 iteration : 0.663300
# cost after 240 iteration : 0.662505
# cost after 250 iteration : 0.661715
# cost after 260 iteration : 0.660928
# cost after 270 iteration : 0.660144
# cost after 280 iteration : 0.659364
# cost after 290 iteration : 0.658588
# cost after 300 iteration : 0.657815
# cost after 310 iteration : 0.657045
# cost after 320 iteration : 0.656279
# cost after 330 iteration : 0.655516
# cost after 340 iteration : 0.654757
# cost after 350 iteration : 0.654000
# cost after 360 iteration : 0.653247
# cost after 370 iteration : 0.652498
# cost after 380 iteration : 0.651751
# cost after 390 iteration : 0.651008
# cost after 400 iteration : 0.650267
# cost after 410 iteration : 0.649530
# cost after 420 iteration : 0.648796
# cost after 430 iteration : 0.648065
# cost after 440 iteration : 0.647337
# cost after 450 iteration : 0.646612
# cost after 460 iteration : 0.645891
# cost after 470 iteration : 0.645172
# cost after 480 iteration : 0.644456
# cost after 490 iteration : 0.643742
# cost after 500 iteration : 0.643032
# cost after 510 iteration : 0.642325
# cost after 520 iteration : 0.641620
# cost after 530 iteration : 0.640919
# cost after 540 iteration : 0.640220
# cost after 550 iteration : 0.639524
# cost after 560 iteration : 0.638830
# cost after 570 iteration : 0.638140
# cost after 580 iteration : 0.637452
# cost after 590 iteration : 0.636766
# cost after 600 iteration : 0.636084
# cost after 610 iteration : 0.635404
# cost after 620 iteration : 0.634727
# cost after 630 iteration : 0.634052
# cost after 640 iteration : 0.633380
# cost after 650 iteration : 0.632710
# cost after 660 iteration : 0.632043
# cost after 670 iteration : 0.631379
# cost after 680 iteration : 0.630717
# cost after 690 iteration : 0.630057
# cost after 700 iteration : 0.629400
# cost after 710 iteration : 0.628746
# cost after 720 iteration : 0.628094
# cost after 730 iteration : 0.627444
# cost after 740 iteration : 0.626796
# cost after 750 iteration : 0.626152
# cost after 760 iteration : 0.625509
# cost after 770 iteration : 0.624869
# cost after 780 iteration : 0.624231
# cost after 790 iteration : 0.623595
# cost after 800 iteration : 0.622962
# cost after 810 iteration : 0.622331
# cost after 820 iteration : 0.621702
# cost after 830 iteration : 0.621076
# cost after 840 iteration : 0.620452
# cost after 850 iteration : 0.619830
# cost after 860 iteration : 0.619210
# cost after 870 iteration : 0.618592
# cost after 880 iteration : 0.617977
# cost after 890 iteration : 0.617364
# cost after 900 iteration : 0.616753
# cost after 910 iteration : 0.616144
# cost after 920 iteration : 0.615537
# cost after 930 iteration : 0.614932
# cost after 940 iteration : 0.614330
# cost after 950 iteration : 0.613729
# cost after 960 iteration : 0.613131
# cost after 970 iteration : 0.612534
# cost after 980 iteration : 0.611940
# cost after 990 iteration : 0.611348
# cost after 1000 iteration : 0.610757
# cost after 1010 iteration : 0.610169
# cost after 1020 iteration : 0.609583
# cost after 1030 iteration : 0.608998
# cost after 1040 iteration : 0.608416
# cost after 1050 iteration : 0.607836
# cost after 1060 iteration : 0.607257
# cost after 1070 iteration : 0.606681
# cost after 1080 iteration : 0.606106
# cost after 1090 iteration : 0.605534
# cost after 1100 iteration : 0.604963
# cost after 1110 iteration : 0.604394
# cost after 1120 iteration : 0.603827
# cost after 1130 iteration : 0.603262
# cost after 1140 iteration : 0.602699
# cost after 1150 iteration : 0.602138
# cost after 1160 iteration : 0.601578
# cost after 1170 iteration : 0.601020
# cost after 1180 iteration : 0.600465
# cost after 1190 iteration : 0.599911
# cost after 1200 iteration : 0.599358
# cost after 1210 iteration : 0.598808
# cost after 1220 iteration : 0.598259
# cost after 1230 iteration : 0.597712
# cost after 1240 iteration : 0.597167
# cost after 1250 iteration : 0.596624
# cost after 1260 iteration : 0.596082
# cost after 1270 iteration : 0.595542
# cost after 1280 iteration : 0.595004
# cost after 1290 iteration : 0.594468
# cost after 1300 iteration : 0.593933
# cost after 1310 iteration : 0.593400
# cost after 1320 iteration : 0.592868
# cost after 1330 iteration : 0.592339
# cost after 1340 iteration : 0.591811
# cost after 1350 iteration : 0.591284
# cost after 1360 iteration : 0.590760
# cost after 1370 iteration : 0.590237
# cost after 1380 iteration : 0.589715
# cost after 1390 iteration : 0.589196
# cost after 1400 iteration : 0.588677
# cost after 1410 iteration : 0.588161
# cost after 1420 iteration : 0.587646
# cost after 1430 iteration : 0.587133
# cost after 1440 iteration : 0.586621
# cost after 1450 iteration : 0.586111
# cost after 1460 iteration : 0.585602
# cost after 1470 iteration : 0.585095
# cost after 1480 iteration : 0.584590
# cost after 1490 iteration : 0.584086
# cost after 1500 iteration : 0.583583
# cost after 1510 iteration : 0.583082
# cost after 1520 iteration : 0.582583
# cost after 1530 iteration : 0.582085
# cost after 1540 iteration : 0.581589
# cost after 1550 iteration : 0.581094
# cost after 1560 iteration : 0.580601
# cost after 1570 iteration : 0.580109
# cost after 1580 iteration : 0.579619
# cost after 1590 iteration : 0.579130
# cost after 1600 iteration : 0.578643
# cost after 1610 iteration : 0.578157
# cost after 1620 iteration : 0.577673
# cost after 1630 iteration : 0.577190
# cost after 1640 iteration : 0.576708
# cost after 1650 iteration : 0.576228
# cost after 1660 iteration : 0.575749
# cost after 1670 iteration : 0.575272
# cost after 1680 iteration : 0.574796
# cost after 1690 iteration : 0.574322
# cost after 1700 iteration : 0.573849
# cost after 1710 iteration : 0.573377
# cost after 1720 iteration : 0.572907
# cost after 1730 iteration : 0.572438
# cost after 1740 iteration : 0.571971
# cost after 1750 iteration : 0.571505
# cost after 1760 iteration : 0.571040
# cost after 1770 iteration : 0.570577
# cost after 1780 iteration : 0.570115
# cost after 1790 iteration : 0.569654
# cost after 1800 iteration : 0.569195
# cost after 1810 iteration : 0.568737
# cost after 1820 iteration : 0.568280
# cost after 1830 iteration : 0.567825
# cost after 1840 iteration : 0.567371
# cost after 1850 iteration : 0.566918
# cost after 1860 iteration : 0.566467
# cost after 1870 iteration : 0.566017
# cost after 1880 iteration : 0.565568
# cost after 1890 iteration : 0.565121
# cost after 1900 iteration : 0.564675
# cost after 1910 iteration : 0.564230
# cost after 1920 iteration : 0.563786
# cost after 1930 iteration : 0.563344
# cost after 1940 iteration : 0.562903
# cost after 1950 iteration : 0.562463
# cost after 1960 iteration : 0.562024
# cost after 1970 iteration : 0.561587
# cost after 1980 iteration : 0.561151
# cost after 1990 iteration : 0.560716
# cost after 2000 iteration : 0.560282
# cost after 2010 iteration : 0.559850
# cost after 2020 iteration : 0.559419
# cost after 2030 iteration : 0.558989
# cost after 2040 iteration : 0.558560
# cost after 2050 iteration : 0.558132
# cost after 2060 iteration : 0.557706
# cost after 2070 iteration : 0.557281
# cost after 2080 iteration : 0.556857
# cost after 2090 iteration : 0.556434
# cost after 2100 iteration : 0.556012
# cost after 2110 iteration : 0.555592
# cost after 2120 iteration : 0.555173
# cost after 2130 iteration : 0.554755
# cost after 2140 iteration : 0.554338
# cost after 2150 iteration : 0.553922
# cost after 2160 iteration : 0.553507
# cost after 2170 iteration : 0.553094
# cost after 2180 iteration : 0.552681
# cost after 2190 iteration : 0.552270
# cost after 2200 iteration : 0.551860
# cost after 2210 iteration : 0.551451
# cost after 2220 iteration : 0.551043
# cost after 2230 iteration : 0.550637
# cost after 2240 iteration : 0.550231
# cost after 2250 iteration : 0.549827
# cost after 2260 iteration : 0.549423
# cost after 2270 iteration : 0.549021
# cost after 2280 iteration : 0.548620
# cost after 2290 iteration : 0.548220
# cost after 2300 iteration : 0.547821
# cost after 2310 iteration : 0.547423
# cost after 2320 iteration : 0.547026
# cost after 2330 iteration : 0.546630
# cost after 2340 iteration : 0.546235
# cost after 2350 iteration : 0.545842
# cost after 2360 iteration : 0.545449
# cost after 2370 iteration : 0.545058
# cost after 2380 iteration : 0.544667
# cost after 2390 iteration : 0.544278
# cost after 2400 iteration : 0.543890
# cost after 2410 iteration : 0.543502
# cost after 2420 iteration : 0.543116
# cost after 2430 iteration : 0.542731
# cost after 2440 iteration : 0.542346
# cost after 2450 iteration : 0.541963
# cost after 2460 iteration : 0.541581
# cost after 2470 iteration : 0.541200
# cost after 2480 iteration : 0.540820
# cost after 2490 iteration : 0.540441
# cost after 2500 iteration : 0.540062
# cost after 2510 iteration : 0.539685
# cost after 2520 iteration : 0.539309
# cost after 2530 iteration : 0.538934
# cost after 2540 iteration : 0.538560
# cost after 2550 iteration : 0.538187
# cost after 2560 iteration : 0.537815
# cost after 2570 iteration : 0.537443
# cost after 2580 iteration : 0.537073
# cost after 2590 iteration : 0.536704
# cost after 2600 iteration : 0.536336
# cost after 2610 iteration : 0.535968
# cost after 2620 iteration : 0.535602
# cost after 2630 iteration : 0.535236
# cost after 2640 iteration : 0.534872
# cost after 2650 iteration : 0.534508
# cost after 2660 iteration : 0.534146
# cost after 2670 iteration : 0.533784
# cost after 2680 iteration : 0.533424
# cost after 2690 iteration : 0.533064
# cost after 2700 iteration : 0.532705
# cost after 2710 iteration : 0.532347
# cost after 2720 iteration : 0.531990
# cost after 2730 iteration : 0.531634
# cost after 2740 iteration : 0.531279
# cost after 2750 iteration : 0.530925
# cost after 2760 iteration : 0.530571
# cost after 2770 iteration : 0.530219
# cost after 2780 iteration : 0.529867
# cost after 2790 iteration : 0.529517
# cost after 2800 iteration : 0.529167
# cost after 2810 iteration : 0.528818
# cost after 2820 iteration : 0.528470
# cost after 2830 iteration : 0.528123
# cost after 2840 iteration : 0.527777
# cost after 2850 iteration : 0.527432
# cost after 2860 iteration : 0.527087
# cost after 2870 iteration : 0.526744
# cost after 2880 iteration : 0.526401
# cost after 2890 iteration : 0.526059
# cost after 2900 iteration : 0.525718
# cost after 2910 iteration : 0.525378
# cost after 2920 iteration : 0.525039
# cost after 2930 iteration : 0.524701
# cost after 2940 iteration : 0.524363
# cost after 2950 iteration : 0.524026
# cost after 2960 iteration : 0.523691
# cost after 2970 iteration : 0.523356
# cost after 2980 iteration : 0.523022
# cost after 2990 iteration : 0.522688
#
# Train accuracy: 87.2 %
#
# Test accuracy: 89.69072164948454 %
